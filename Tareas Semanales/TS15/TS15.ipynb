# %% [markdown]
# # Tarea Semanal 15

# %% [markdown]
# ![TS15_1.jpg](attachment:TS15_1.jpg)

# %% [markdown]
# ![image-10.png](attachment:image-10.png)
# ![image-9.png](attachment:image-9.png)
# ![image-4.png](attachment:image-4.png)
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# En S21 podemos verificar el comportamiento como pasabajos que estabamos buscando. Con S11 vemos la onda reflejada que se ve desde el puerto 1. Vemos que en 0 tenemos uno poca onda reflejada y en el centro de la banda de paso tenemos todavia aun mas. Cuando ya vamos a infinito se ve que tiende a 0dB es decir que se refleja toda la onda, lo cual tiene sentido ya que es un pasabajos.

# %% [markdown]
# Aqui debajo dejo algunos calculos que realice con python para resolver las cuentas

# %%
import numpy as np

den = [ 1, 0, 8, 0,  1]
roots = np.roots(den)
print(f'roots: {roots}')
# Out:
# roots: [0.+0.92387953j 0.-0.92387953j 0.+0.38268343j 0.-0.38268343j]

# %%
import numpy as np
import scipy.signal as sig
import splane as tc2

# verificación Cheby1
z,p,k = sig.cheb1ap(4, 1)
num_pb, den_pb = sig.zpk2tf(z,p,k)

print('\n\n')
print('--------------------------------')
print('Transferencia pasabajo prototipo')
print('--------------------------------')
tc2.pretty_print_lti(num_pb, den_pb)
# Out:
# --------------------------------
# Transferencia pasabajo prototipo
# --------------------------------
# $\displaystyle \frac{0.2457 }{s^4 + s^3 \,\, 0.9528 + s^2 \,\, 1.454 + s \,\, 0.7426 + 0.2756 }$

# %%
import numpy as np

den = [ 1, 0.9528, 1.454, 0.7426,  0.2756]
roots = np.roots(den)
print(f'roots: {roots}')
# Out:
# roots: [-0.13957881+0.98342457j -0.13957881-0.98342457j -0.33682119+0.40729958j
#  -0.33682119-0.40729958j]

# %%
import numpy as np

den = [ 1.354, 0.9528, 2.445, 0.7426,  0.3978]
roots = np.roots(den)
print(f'roots: {roots}')
# Out:
# roots: [-0.1929134 +1.20337191j -0.1929134 -1.20337191j -0.15893298+0.41537968j
#  -0.15893298-0.41537968j]
