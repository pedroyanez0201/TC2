# %% [markdown]
# # Tarea Semanal 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Disculpe lo desprolijo, para la semana que viene en la entrega lo dejo mejor.
